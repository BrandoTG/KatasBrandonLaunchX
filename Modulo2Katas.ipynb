# %% [markdown]
# # Creando el ambiente virtual

# %% [markdown]
# ![imagen-4.png](https://i.imgur.com/1I6VmJK.png)

# %% [markdown]
# # Instalar una biblioteca

# %% [markdown]
# ![imagen-2.png](https://i.imgur.com/tAbB3pT.png)
